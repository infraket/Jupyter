# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('../ml/List of Play-to-Earn Games 2021 _ Data40.com - Table.csv')

# %% [markdown]
# This survey includes the short list of 200 units, with parameters for each:
#
#  - Links to Pay to Earn Game Sites
#  - Released games and games discovered in development
#  - Games based on Cryptocurrencies and NFTs
#  - PC/MAC versions of the game
#  - Mobile versions of games or including game resource management through a mobile application
#  - Browser versions of games or those that include game resource management through the browser
#  - Games site traffic for September 2021

# %%
data
# Out:
#                             Link Traffic 09.2021 Based on Crypto  \
# 0        https://0xuniverse.com/          42 990               X
# 1        https://0xwarriors.com/           1 884               X
# 2    https://22racingseries.com/             758               X
# 3          https://7-gnomes.org/          39 526               -
# 4       https://9livesarena.com/          34 166               X
# ..                           ...             ...             ...
# 195    https://dashleague.games/             912               X
# 196        https://deathroad.io/         315 865               X
# 197    https://decentraland.org/         800 506               X
# 198       https://decimated.net/           8 448               X
# 199    https://defikingdoms.com/         407 057               X
#
#     In Development PC/MAC App Browser Play/Interaction Mobile Play/Interaction
# 0                -          -                        X                       X
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Link                      200 non-null    object
#  1   Traffic 09.2021           200 non-null    object
#  2   Based on Crypto           200 non-null    object
#  3   In Development            200 non-null    object
#  4   PC/MAC App                200 non-null    object
#  5   Browser Play/Interaction  200 non-null    object
#  6   Mobile Play/Interaction   200 non-null    object
# dtypes: object(7)
# memory usage: 11.1+ KB

# %%
data.replace("X","1",inplace=True)
data.replace("-","0",inplace=True)

# %%
data_p2e = data[data.Link.isin(['https://axieinfinity.com/','https://www.sandbox.game/en/','https://decentraland.org/',
                     'https://staratlas.com/','https://aurory.io/','https://www.myneighboralice.com/',
                     'https://galaxyfightclub.com/','https://wizardia.io/',
                    'https://crazydefenseheroes.com/','https://illuvium.io/','https://www.voxies.io/',
                     'https://alienworlds.io/','https://www.leagueofkingdoms.com/','https://godsunchained.com/',
                     'https://nine-chronicles.com/','https://www.aavegotchi.com/','https://splinterlands.com/',
                     'https://battleofguardians.com/','https://metal-war.com/','https://sorare.com/',
                     'https://splinterlands.com/','https://staratlas.com/'
                     
                    ])]

# %%
data_p2e.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 16 to 197
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Link                      5 non-null      object
#  1   Traffic 09.2021           5 non-null      object
#  2   Based on Crypto           5 non-null      object
#  3   In Development            5 non-null      object
#  4   PC/MAC App                5 non-null      object
#  5   Browser Play/Interaction  5 non-null      object
#  6   Mobile Play/Interaction   5 non-null      object
# dtypes: object(7)
# memory usage: 320.0+ bytes

# %%
data_p2e
# Out:
#                                 Link Traffic 09.2021 Based on Crypto  \
# 16           https://alienworlds.io/       2 557 000               1
# 34                https://aurory.io/         430 698               1
# 39         https://axieinfinity.com/      25 970 000               1
# 132  https://crazydefenseheroes.com/         172 834               1
# 197        https://decentraland.org/         800 506               1
#
#     In Development PC/MAC App Browser Play/Interaction Mobile Play/Interaction
# 16               0          0                        1                       0
# 34               1          1                        0                       1
# 39               0          1                        0                       1
# 132              0          0                        1                       1
# 197              0          0                        1                       0
