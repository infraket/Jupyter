# %%
import pandas as pd
import numpy as np

# %%
xl = pd.ExcelFile('ООО_Внимание_к_деталям.xlsx')

print(xl.sheet_names)
# Out:
# ['Справочник точек', 'Выручка по обучающей выборке']

# %%
df1 = xl.parse('Справочник точек')
df2 = xl.parse('Выручка по обучающей выборке')
# Out:
# C:\Users\aveac\AppData\Local\Temp/ipykernel_4368/122144240.py:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype={value.dtype})
#   df1 = xl.parse('Справочник точек')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id точки             245 non-null    float64
#  1   Адрес                246 non-null    object
#  2   Широта               242 non-null    float64
#  3   Долгота              242 non-null    float64
#  4   Дата открытия        245 non-null    object
#  5   Дата закрытия        9 non-null      datetime64[ns]
#  6   Площадь магазина     246 non-null    int64
#  7   Тип входа            244 non-null    object
#  8   Площадь ТЦ           204 non-null    float64
#  9   Формат магазина      246 non-null    object
#  10  Парковка             226 non-null    object
#  11  Этаж                 241 non-null    object
#  12  Время работы         232 non-null    object
#  13  Заполненность ТЦ     182 non-null    float64
#  14  Рядом с эскалатором  246 non-null    int64
# ...

# %% [markdown]
# Сколько магазинов формата стрит в тестовой выборке? 7

# %%
df1['Формат магазина'].value_counts()
# Out:
# ТЦ         191
# Мини ТЦ     28
# Street      18
# Стрит        4
# Мини-ТЦ      3
# Strееt       1
# Стрт         1
# Name: Формат магазина, dtype: int64

# %%
df1['Выборка'].value_counts()
# Out:
# Обучающая    156
# Тестовая      77
# -             10
# Тест           1
# Обyчающая      1
# Name: Выборка, dtype: int64

# %%
count_mag = df1[df1['Выборка'].isin(['Тестовая','тест']) & df1['Формат магазина'].isin(['Street','Стрит','Стрт','Strееt'])]
count_mag
# Out:
#      id точки                                              Адрес     Широта  \
# 72    42059.0          г. Санкт-Петербург, Невский пр., дом № 27  30.327007
# 74    42072.0  г. Санкт-Петербург, Невский пр., дом № 90-92, ...  30.352412
# 119   42288.0  Краснодарский край, г. Сочи, ул. Навагинская, ...  39.723699
# 130   42345.0  Ленинградская обл, г. Выборг, ул. Северная, до...  28.750976
# 155   42466.0  Новгородская обл, г. Великий Новгород, ул. Газ...  31.271550
# 164   42499.0  Оренбургская обл, г. Оренбург, ул. Володарског...  55.102543
# 224   42792.0  Ставропольский край, Пятигорск, улица Крайнего...  43.070993
#
#        Долгота        Дата открытия Дата закрытия  Площадь магазина  \
# 72   59.935056  2005-03-03 00:00:00           NaT               234
# 74   59.932428  2003-09-16 00:00:00           NaT               136
# 119  43.587014  2002-04-06 00:00:00           NaT               172
# 130  60.711041  2006-06-01 00:00:00           NaT               150
# ...

# %%
print(f'Магазинов формата стрит в тестовой выборке {len(count_mag)}')
# Out:
# Магазинов формата стрит в тестовой выборке 7

# %%
df2
# Out:
#       id точки     2015-01-01     2015-02-01     2015-03-01     2015-04-01  \
# 0      11366.0  245709.342667  301024.685000  406199.782258  295602.853000
# 1      11810.0  270245.842066  297964.820199  406198.175918  232433.263996
# 2      15041.0  171972.976000  198141.440000  260215.741935  205316.010644
# 3      15775.0  409032.989736  468816.460949  582717.510920  442807.529886
# 4      16102.0  437693.191667  510077.198214  602107.617742  465779.798333
# ..         ...            ...            ...            ...            ...
# 150  2634000.0  341009.722000  413489.085501  518426.278387  376071.505667
# 151  2634008.0  270923.715000  404737.144643  470433.872222  401063.781000
# 152  2634011.0  378429.753517  350607.477988  482925.193552  367225.245935
# 153  2633936.0            NaN            NaN            NaN            NaN
# 154        NaN            NaN            NaN            NaN            NaN
#
#         2015-05-01     2015-06-01     2015-07-01     2015-08-01  \
# ...

# %%
df_mini_id = df1[df1['Формат магазина'].isin(['Мини ТЦ','Мини-ТЦ'])]['id точки'].dropna()

# %%
df_mini_id
# Out:
# 18       18331.0
# 24       18728.0
# 30       41824.0
# 47       41933.0
# 66       42039.0
# 73       42067.0
# 82       42113.0
# 94       42163.0
# 99       42192.0
# 105      42219.0
# 112      42242.0
# 117      42276.0
# 118      42278.0
# 131      42355.0
# 133      42368.0
# 136      42383.0
# 145      42422.0
# 152      42458.0
# 163      42496.0
# 165      42504.0
# 174      42548.0
# 181      42598.0
# 184      42618.0
# 186      42645.0
# 195      42683.0
# 204      42720.0
# 211      42743.0
# 227      42803.0
# 238      42645.0
# 242    2633930.0
# Name: id точки, dtype: float64

# %%
len(df_mini_id)
# Out:
# 30

# %%
df_cash_id = pd.merge(df_mini_id, df2, on="id точки", how='left')

# %%
df_cash_id
# Out:
#      id точки     2015-01-01     2015-02-01     2015-03-01     2015-04-01  \
# 0     18331.0            NaN            NaN            NaN            NaN
# 1     18728.0  337679.020000  505983.520415  615360.263226  500352.832000
# 2     41824.0  294160.860000  332418.278571  420586.925516  343592.490000
# 3     41933.0  109865.820000  126723.117857  152200.364516  107882.820000
# 4     42039.0            NaN            NaN            NaN            NaN
# 5     42067.0  628606.145983  782399.429996  951061.128761  656418.923765
# 6     42113.0            NaN            NaN            NaN            NaN
# 7     42163.0            NaN            NaN            NaN            NaN
# 8     42192.0  151637.321333  216306.985000  277075.327097  180022.309333
# 9     42219.0  157466.511253  202047.920000  234949.409032  177244.293333
# 10    42242.0  264344.055172  348946.371429  415594.606452  266054.000000
# 11    42276.0            NaN            NaN            NaN            NaN
# ...

# %%
df_cash_id.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31 entries, 0 to 30
# Data columns (total 47 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id точки    31 non-null     float64
#  1   2015-01-01  16 non-null     float64
#  2   2015-02-01  16 non-null     float64
#  3   2015-03-01  16 non-null     float64
#  4   2015-04-01  16 non-null     float64
#  5   2015-05-01  16 non-null     float64
#  6   2015-06-01  16 non-null     float64
#  7   2015-07-01  16 non-null     float64
#  8   2015-08-01  16 non-null     float64
#  9   2015-09-01  16 non-null     float64
#  10  2015-10-01  16 non-null     float64
#  11  2015-11-01  16 non-null     object
#  12  2015-12-01  17 non-null     object
#  13  2016-01-01  17 non-null     object
#  14  2016-02-01  18 non-null     object
#  15  2016-03-01  18 non-null     object
#  16  2016-04-01  18 non-null     object
#  17  2016-05-01  18 non-null     object
# ...

# %%
df_cash_id['id точки']
# Out:
# 0       18331.0
# 1       18728.0
# 2       41824.0
# 3       41933.0
# 4       42039.0
# 5       42067.0
# 6       42113.0
# 7       42163.0
# 8       42192.0
# 9       42219.0
# 10      42242.0
# 11      42276.0
# 12      42278.0
# 13      42355.0
# 14      42368.0
# 15      42383.0
# 16      42383.0
# 17      42422.0
# 18      42458.0
# 19      42496.0
# 20      42504.0
# 21      42548.0
# 22      42598.0
# 23      42618.0
# 24      42645.0
# 25      42683.0
# 26      42720.0
# 27      42743.0
# 28      42803.0
# 29      42645.0
# 30    2633930.0
# Name: id точки, dtype: object

# %%
col_mapping = [f"{c[0]}:{c[1]}" for c in enumerate(df_cash_id.columns)]

# %%
col_mapping
# Out:
# ['0:id точки',
#  '1:2015-01-01',
#  '2:2015-02-01',
#  '3:2015-03-01',
#  '4:2015-04-01',
#  '5:2015-05-01',
#  '6:2015-06-01',
#  '7:2015-07-01',
#  '8:2015-08-01',
#  '9:2015-09-01',
#  '10:2015-10-01',
#  '11:2015-11-01',
#  '12:2015-12-01',
#  '13:2016-01-01',
#  '14:2016-02-01',
#  '15:2016-03-01',
#  '16:2016-04-01',
#  '17:2016-05-01',
#  '18:2016-06-01',
#  '19:2016-07-01',
#  '20:2016-08-01',
#  '21:2016-09-01',
#  '22:2016-10-01',
#  '23:2016-11-01',
#  '24:2016-12-01',
#  '25:2017-01-01',
#  '26:2017-02-01',
#  '27:2017-03-01',
#  '28:2017-04-01',
#  '29:2017-05-01',
#  '30:2017-06-01',
#  '31:2017-07-01',
#  '32:2017-08-01',
#  '33:2017-09-01',
#  '34:2017-10-01',
#  '35:2017-11-01',
#  '36:2017-12-01',
#  '37:2018-01-01',
#  '38:2018-02-01',
#  '39:2018-04-01',
#  '40:2018-05-01',
#  '41:2018-06-01',
#  '42:2018-07-01',
#  '43:2018-08-01',
#  '44:2018-09-01',
#  '45:2018-10-01',
#  '46:2018-11-01']

# %%
df_cash_2016 = df_cash_id.iloc[:,np.r_[13:25]]
df_cash_2016
# Out:
#        2016-01-01     2016-02-01     2016-03-01     2016-04-01     2016-05-01  \
# 0             NaN            NaN            NaN            NaN            NaN
# 1       367034.64      518191.52  612575.473548       462814.8   477767.72129
# 2       288251.64  380476.893103  409749.793548      335297.01  341503.345161
# 3        96125.46  131703.051724   166441.23871      103033.83      109410.63
# 4             NaN            NaN            NaN            NaN            NaN
# 5    618664.28442  778685.648276   948356.72129      610125.39  648604.550319
# 6             NaN            NaN            NaN            NaN            NaN
# 7             NaN            NaN            NaN            NaN            NaN
# 8   157156.285333  219535.906897  263464.079355     180751.274  174377.539355
# 9   165361.765333  183196.816166  234128.893793  181151.861333  166158.575484
# 10  262235.282759  341500.413793  413340.774194  278217.413333  253406.967742
# ...

# %%
df_cash_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31 entries, 0 to 30
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   2016-01-01   17 non-null     object
#  1   2016-02-01   18 non-null     object
#  2   2016-03-01   18 non-null     object
#  3   2016-04-01   18 non-null     object
#  4   2016-05-01   18 non-null     object
#  5   2016-06-01   18 non-null     float64
#  6   2016-07-01   19 non-null     float64
#  7   2016-08-01   19 non-null     float64
#  8   2016-09-01   19 non-null     float64
#  9   2016-10-01   19 non-null     float64
#  10  2016-11-01   19 non-null     object
#  11  2016-12-01   19 non-null     object
#  12  average_all  19 non-null     float64
# dtypes: float64(6), object(7)
# memory usage: 3.4+ KB

# %% [markdown]
# Сколько магазинов с бесплатной парковкой? **157**

# %%
df1['Парковка'].value_counts()
# Out:
# бесплатная парковка    156
# нет парковки            34
# платная парковка        31
# 100                      2
# 1000                     1
# 700                      1
# бесплатная паpковка      1
# Name: Парковка, dtype: int64

# %%
count_free_parking = df1[df1['Парковка'].isin(['бесплатная парковка','бесплатная паpковка'])]
count_free_parking
# Out:
#       id точки                                              Адрес      Широта  \
# 0       8955.0   Оренбургская обл, Оренбург г, Шарлыкское ш, д...   55.118272
# 1      11007.0  Алтайский край, г. Барнаул, ул. Малахова, дом ...   83.696799
# 2      11366.0  Амурская область, Благовещенск, улица Мухина, 114  127.510357
# 3      11810.0  Архангельская обл, г. Архангельск , Троицкий п...   40.528249
# 4      15041.0  Архангельская обл, г. Архангельск, Троицкий пр...   40.526317
# ..         ...                                                ...         ...
# 240  2633927.0  Якутск г, Орджоникидзе ул, дом № 38, ТРК "Туйм...  129.728962
# 241  2633929.0  Ямало-Ненецкий АО, г. Новый Уренгой, ул. Сибир...   76.631279
# 242  2633930.0  Ямало-Ненецкий АО, Ноябрьск г, Советская ул, д...   75.465427
# 243  2633935.0  Ярославская обл, г. Ярославль, ул. Победы, дом...   39.869236
# 245  2633948.0  Ярославская обл, Ярославский район, Телегински...   39.783545
#
# ...
