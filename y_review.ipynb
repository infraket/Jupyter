# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
#import plotly.express as px

# %%
movie = pd.read_csv('https://github.com/tkseneee/Dataset/raw/master/movie_metadata.csv')

# %%
movie
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
movie['duration'].isnull().sum()
# Out:
# 15

# %%
movie.isnull().sum()
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               303
# budget                         0
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
movie_copy= movie.copy()

# %%
movie_copy
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
if (movie_copy['duration'].isnull().values.any()):
    movie_copy['duration'].fillna(movie_copy['duration'].median(),inplace = True)

# %%
movie_copy
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN     103.0
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
movie_copy['duration'].isnull().sum()
# Out:
# 0

# %%
m = movie_copy['duration'].mean()
m
# Out:
# 107.18857822724569

# %%
m = round(m,2)

# %%
m
# Out:
# 107.19

# %%
movie_copy[(movie_copy.title_year == 2008.0) & (movie_copy.duration.between(90.0, 120.0)) ][['duration','title_year']]\
.sort_values('duration')
# Out:
#       duration  title_year
# 3119      90.0      2008.0
# 4353      90.0      2008.0
# 4164      90.0      2008.0
# 4435      90.0      2008.0
# 1363      90.0      2008.0
# ...        ...         ...
# 1808     119.0      2008.0
# 4318     119.0      2008.0
# 2145     120.0      2008.0
# 433      120.0      2008.0
# 2762     120.0      2008.0
#
# [160 rows x 2 columns]

# %%
movie_copy[['plot_keywords','imdb_score']]
# Out:
#                                           plot_keywords  imdb_score
# 0                avatar|future|marine|native|paraplegic         7.9
# 1     goddess|marriage ceremony|marriage proposal|pi...         7.1
# 2                   bomb|espionage|sequel|spy|terrorist         6.8
# 3     deception|imprisonment|lawlessness|police offi...         8.5
# 4                                                   NaN         7.1
# ...                                                 ...         ...
# 5038             fraud|postal worker|prison|theft|trial         7.7
# 5039       cult|fbi|hideout|prison escape|serial killer         7.5
# 5040                                                NaN         6.3
# 5041                                                NaN         6.3
# 5042  actress name in title|crush|date|four word tit...         6.6
#
# [5043 rows x 2 columns]

# %%
df = movie_copy[['plot_keywords','imdb_score']][movie_copy['plot_keywords'].str.contains('Love', regex=False, case=False, na=False)]

# %%
round(df['imdb_score'].mean(),2)
# Out:
# 6.58

# %%
df_b = movie_copy['budget']

# %%
df_b_not = df_b.replace({'\$': '', ',': ''}, regex=True).astype(float)

# %%
df_b
# Out:
# 0       237000000.0$
# 1       300000000.0$
# 2       245000000.0$
# 3       250000000.0$
# 4               0.0$
#             ...
# 5038            0.0$
# 5039            0.0$
# 5040         1400.0$
# 5041            0.0$
# 5042         1100.0$
# Name: budget, Length: 5043, dtype: object

# %%
df_b_not.median()
# Out:
# 15000000.0
